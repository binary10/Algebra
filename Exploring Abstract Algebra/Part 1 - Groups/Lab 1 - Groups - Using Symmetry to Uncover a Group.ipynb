# %% [markdown]
# # Groups: Lab No. 1
# ## Using Symmetry to Uncover Groups
#
# **Goal.** Discover properties of groups by studying the symmetris of a regular triangle.

# %%
import os

# %% [markdown]
# # Title

# %% [markdown]
# # Title
